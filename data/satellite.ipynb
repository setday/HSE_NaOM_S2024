# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_json("Satellite_trajectory.json")

# %%
x_coord = [data['current_state'][i]['x'] for i in range(1000)]
z_coord = [data['current_state'][i]['z'] for i in range(1000)]

# %%
plt.plot(x_coord, z_coord, '.', color='black')
